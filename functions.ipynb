# %%
# table

table = []

# %%
# CARD DECK

def build_deck():
    suits = ["Hearts", "Spade", "Clubs", "Diamonds"]
    cards_numbers = ["A", "K", "Q", "J", "10", "9", "8", "7", "6", "5", "4", "3", "2"]

    return[(value, suit) for value in cards_numbers for suit in suits]


#card_deck = build_deck ()
#card_deck
#len(card_deck)

# %%
#PLAYER COUNT

def counting_players():
    try:
        num_of_players = int(input("How many players are playing today?"))
    except ValueError:
        print("It needs to be a number")
        counting_players()
#number of players

    def create_player(num):
        return [{"name": "", "cards": "", "blind": "", "money": 1000} for i in range(0,num)]
        
    has_decided= False
    while not has_decided:
        if num_of_players > 1 and num_of_players < 7:
    # put the player creating logic DICTIONARY! 
            return create_player(num_of_players)
        else:
            try:
                num_of_players = int(input("How many players are playing? it has to be between 1-6"))
            except ValueError:
                print("It needs to be a number")

# %%
##counting_players()

test_player_list = [{'name': 'Hugo', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Gaby', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Axel', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Lisa', 'cards': '', 'blind': '', 'money': 1000}]

# %%
# player name

def ask_player_name(player_list):
    for index, player in enumerate(player_list):
        player["name"] = input("What is your name Player {}".format(index +1))

ask_player_name(test_player_list)
#print(test_player_list)

#storage the name of the player in dictionary

# %%
1 #Deck shuffle
import random

def shuffle_deck(deck):
    random.shuffle(deck)

# %%
my_deck = build_deck()
print(my_deck)
shuffle_deck(my_deck)
print(my_deck)
# Out:
# [('A', 'Hearts'), ('A', 'Spade'), ('A', 'Clubs'), ('A', 'Diamonds'), ('K', 'Hearts'), ('K', 'Spade'), ('K', 'Clubs'), ('K', 'Diamonds'), ('Q', 'Hearts'), ('Q', 'Spade'), ('Q', 'Clubs'), ('Q', 'Diamonds'), ('J', 'Hearts'), ('J', 'Spade'), ('J', 'Clubs'), ('J', 'Diamonds'), ('10', 'Hearts'), ('10', 'Spade'), ('10', 'Clubs'), ('10', 'Diamonds'), ('9', 'Hearts'), ('9', 'Spade'), ('9', 'Clubs'), ('9', 'Diamonds'), ('8', 'Hearts'), ('8', 'Spade'), ('8', 'Clubs'), ('8', 'Diamonds'), ('7', 'Hearts'), ('7', 'Spade'), ('7', 'Clubs'), ('7', 'Diamonds'), ('6', 'Hearts'), ('6', 'Spade'), ('6', 'Clubs'), ('6', 'Diamonds'), ('5', 'Hearts'), ('5', 'Spade'), ('5', 'Clubs'), ('5', 'Diamonds'), ('4', 'Hearts'), ('4', 'Spade'), ('4', 'Clubs'), ('4', 'Diamonds'), ('3', 'Hearts'), ('3', 'Spade'), ('3', 'Clubs'), ('3', 'Diamonds'), ('2', 'Hearts'), ('2', 'Spade'), ('2', 'Clubs'), ('2', 'Diamonds')]
# [('K', 'Spade'), ('2', 'Diamonds'), ('Q', 'Hearts'), ('8', 'Spade'), ('9', 'Hearts'), ('A', 'Hearts'), ('9', 'Diamonds'), ('7', 'Diamonds'), ('5', 'Spade'), ('2', 'Clubs'), ('3', 'Clubs'), ('10', 'Diamonds'), ('Q', 'Diamonds'), ('10', 'Hearts'), ('J', 'Hearts'), ('A', 'Spade'), ('10', 'Clubs'), ('8', 'Diamonds'), ('J', 'Spade'), ('K', 'Hearts'), ('6', 'Diamonds'), ('3', 'Diamonds'), ('6', 'Clubs'), ('7', 'Spade'), ('9', 'Spade'), ('3', 'Spade'), ('9', 'Clubs'), ('10', 'Spade'), ('6', 'Spade'), ('2', 'Spade'), ('5', 'Diamonds'), ('8', 'Hearts'), ('A', 'Diamonds'), ('7', 'Hearts'), ('6', 'Hearts'), ('Q', 'Clubs'), ('8', 'Clubs'), ('K', 'Diamonds'), ('3', 'Hearts'), ('J', 'Diamonds'), ('K', 'Clubs'), ('4', 'Clubs'), ('A', 'Clubs'), ('4', 'Diamonds'), ('5', 'Clubs'), ('4', 'Hearts'), ('7', 'Clubs'), ('2', 'Hearts'), ('5', 'Hearts'), ('4', 'Spade'), ('J', 'Clubs'), ('Q', 'Spade')]

# %%
def assign_place(player_list):
    random.shuffle(player_list)

# %%
#{'name': 'Hugo', 'cards': 'insert cards', 'blind': '', 'money': 1000}
#{'name': 'Hugo', 'cards': '', 'blind': '', 'money': 1000}
#{'name': 'Hugo', 'cards': '', 'blind': '', 'money': 1000}
#{'name': 'Hugo', 'cards': '', 'blind': '', 'money': 1000}
#player["cards"] = [card1,card5] 
#player["cards"] = [card2,card6] 
#player["cards"] = [card3,card7] 
#player["cards"] = [card4,card8] 


def deal_cards(player_list,deck):
        counter = 0
        
        for index, card in enumerate(deck[:len(player_list)*2]):
                if index < len(player_list):
                        player_list[index]["cards"] = card
                elif index >= len(player_list):
                        index = counter
                        counter += 1
                        player_list[index]["cards"] = [player_list[index].get("cards"), card]
        

        remove_card(deck, 2*len(player_list))

# %%
test_player_list = [{'name': 'Hugo', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Gaby', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Axel', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Lisa', 'cards': '', 'blind': '', 'money': 1000}]
test_deck = build_deck()

test_deck
deal_cards(test_player_list,test_deck)
print(test_deck)

test_deck
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       1 test_player_list = [{'name': 'Hugo', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Gaby', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Axel', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Lisa', 'cards': '', 'blind': '', 'money': 1000}]
#       2 test_deck = build_deck()
#       3
#       4 test_deck
# ----> 5 deal_cards(test_player_list,test_deck)
#       6 print(test_deck)
#       7
#       8 test_deck
#
# Cell In[22], line 23, in deal_cards(player_list, deck)
#      19                         counter += 1
#      20                         player_list[index]["cards"] = [player_list[index].get("cards"), card]
#      21
#      22
# ---> 23         remove_card(deck, 2*len(player_list))
#
# NameError: name 'remove_card' is not defined

# %%
print(assign_place(test_player_list))
print(test_player_list)
# Out:
# None
# [{'name': 'Axel', 'location': '', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Taga', 'location': '', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Gaby', 'location': '', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Lisa', 'location': '', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Hugo', 'location': '', 'cards': '', 'blind': '', 'money': 1000}]

# %%
def switch_places(player_list):
    player_list.append(player_list[0])
    player_list.remove(player_list[0])

# %%
test_player_list = [{'name': 'Hugo', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Gaby', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Axel', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Lisa', 'cards': '', 'blind': '', 'money': 1000}]
print(test_player_list)
switch_places(test_player_list)
print(test_player_list)
# Out:
# [{'name': 'Hugo', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Gaby', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Axel', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Lisa', 'cards': '', 'blind': '', 'money': 1000}]
# [{'name': 'Gaby', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Axel', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Lisa', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Hugo', 'cards': '', 'blind': '', 'money': 1000}]

# %%
#REMOVE CARDS from DECK 

def remove_card(deck, i):
    del deck[:i]

# %%
#test_deck = build_deck()
#print (test_deck)
#remove_card (test_deck, 1)
#print(test_deck)
# Out:
# [('A', 'Hearts'), ('A', 'Spade'), ('A', 'Clubs'), ('A', 'Diamonds'), ('K', 'Hearts'), ('K', 'Spade'), ('K', 'Clubs'), ('K', 'Diamonds'), ('Q', 'Hearts'), ('Q', 'Spade'), ('Q', 'Clubs'), ('Q', 'Diamonds'), ('J', 'Hearts'), ('J', 'Spade'), ('J', 'Clubs'), ('J', 'Diamonds'), ('10', 'Hearts'), ('10', 'Spade'), ('10', 'Clubs'), ('10', 'Diamonds'), ('9', 'Hearts'), ('9', 'Spade'), ('9', 'Clubs'), ('9', 'Diamonds'), ('8', 'Hearts'), ('8', 'Spade'), ('8', 'Clubs'), ('8', 'Diamonds'), ('7', 'Hearts'), ('7', 'Spade'), ('7', 'Clubs'), ('7', 'Diamonds'), ('6', 'Hearts'), ('6', 'Spade'), ('6', 'Clubs'), ('6', 'Diamonds'), ('5', 'Hearts'), ('5', 'Spade'), ('5', 'Clubs'), ('5', 'Diamonds'), ('4', 'Hearts'), ('4', 'Spade'), ('4', 'Clubs'), ('4', 'Diamonds'), ('3', 'Hearts'), ('3', 'Spade'), ('3', 'Clubs'), ('3', 'Diamonds'), ('2', 'Hearts'), ('2', 'Spade'), ('2', 'Clubs'), ('2', 'Diamonds')]
# [('A', 'Spade'), ('A', 'Clubs'), ('A', 'Diamonds'), ('K', 'Hearts'), ('K', 'Spade'), ('K', 'Clubs'), ('K', 'Diamonds'), ('Q', 'Hearts'), ('Q', 'Spade'), ('Q', 'Clubs'), ('Q', 'Diamonds'), ('J', 'Hearts'), ('J', 'Spade'), ('J', 'Clubs'), ('J', 'Diamonds'), ('10', 'Hearts'), ('10', 'Spade'), ('10', 'Clubs'), ('10', 'Diamonds'), ('9', 'Hearts'), ('9', 'Spade'), ('9', 'Clubs'), ('9', 'Diamonds'), ('8', 'Hearts'), ('8', 'Spade'), ('8', 'Clubs'), ('8', 'Diamonds'), ('7', 'Hearts'), ('7', 'Spade'), ('7', 'Clubs'), ('7', 'Diamonds'), ('6', 'Hearts'), ('6', 'Spade'), ('6', 'Clubs'), ('6', 'Diamonds'), ('5', 'Hearts'), ('5', 'Spade'), ('5', 'Clubs'), ('5', 'Diamonds'), ('4', 'Hearts'), ('4', 'Spade'), ('4', 'Clubs'), ('4', 'Diamonds'), ('3', 'Hearts'), ('3', 'Spade'), ('3', 'Clubs'), ('3', 'Diamonds'), ('2', 'Hearts'), ('2', 'Spade'), ('2', 'Clubs'), ('2', 'Diamonds')]

# %%
#DEALING CARDS (IN TABLE) - 3 first cards

table = []

def deal_cards_to_table(deck, table, i):
    for j in range(0,i):
        table.append(deck[0])
        remove_card(deck,1)

test_deck

deal_cards_to_table(test_deck, table, 3)
test_deck
table
# Out:
# [('8', 'Spade'), ('8', 'Clubs'), ('8', 'Diamonds')]

# %%
#POT & PAYOUT


test_player_list = [{'name': 'Hugo', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Gaby', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Axel', 'cards': '', 'blind': '', 'money': 1000}, {'name': 'Lisa', 'cards': '', 'blind': '', 'money': 1000}]


def create_pot(player_list):
    ## this function return a dictionary with name and cero amount {'Hugo': 0, 'Gaby': 0, 'Axel': 0, 'Lisa': 0}
    pot = {"name": "", "bet": 0, "total_pot": 0}
    return { player.get("name"): 0 for player in player_list }
    
create_pot(test_player_list)
# Out:
# {'Hugo': 0, 'Gaby': 0, 'Axel': 0, 'Lisa': 0}

# %%
pot = create_pot(test_player_list)

def player_options(player,pot):
    print("123")
    option_list = ["fold"]
    if sum(pot.values()) == 0:
        option_list.append("check")
    elif max(pot.values()) > pot.get(player):
        option_list.append("call")

    option_list.append("raise")

    return option_list
# Out:
# 123
# ['Fold', 'Check', 'Raise']

# %%
def has_money(player,player_list, ammount):
    for i in player_list:
        if i["name"] == player:
            if ammount > player.get("money"):
                return False
    return True

# %%
def bet(player,pot,player_list,ammount):
    if has_money(player,player_list,ammount):
        for i in player_list:
            if i["name"] == player:
                i["money"] = i["money"] - ammount
                pot[player] = pot[player] + ammount
                return True

    else:
        return False

# %%
def player_decision(player,pot,player_list):
    options = player_options(player,pot)
    player_choice = input("What option you choose? {}".format(options(player,pot)))

    if player_choice.lower() in options:
        if player_choice.lower() == "fold":
            pot.remove(player)
        elif player_choice.lower() == "call":
            value_to_pay = max(pot.values()) - pot.get(player)
            player_asnwer = input("You will call {}€! write yes to procede".format(value_to_pay))
            if player_asnwer.lower().startswith("y"):
                if bet():
                    return True, "call"
                else:
                    input("You had no money for that call, we will fold for you :)")
            
        elif player_choice.lower() == "raise":

        else:
            #fold
    else:
        bet(player,pot,player_list)

# %%
    player_choice = input("What option you choose? {}".format(options("Hugo",pot)))
# Out:
# 123

# %%
## cards ranking

def ranked_cards(table, player_list):
    for i in player_list:
        i["cards"] = [i["cards"] + table] 


from collections import Counter

    for player in player_list:
        if Counter([x for (x,y) in player["cards"]]) ==2:
            pair = [name, 1]

    for player in player_list:
        if Counter([x for (x,y) in player["cards"]]) ==3:
            two_pair = [name, 2]

    for player in player_list:
    if Counter([x for (x,y) in player["cards"]]) ==4:
        three_kind = [name, 3]

    for player in player_list:
    if Counter([x for (x,y) in player["cards"]]) ==5:
        flush = [name, 1]
# Out:
#   Cell In[31], line 12
#     for player in player_list:
#     ^
# IndentationError: unexpected indent

# %%
print (test_player_list)
# Out:
# [{'name': 'Hugo', 'cards': [('A', 'Hearts'), ('K', 'Hearts')], 'blind': '', 'money': 1000}, {'name': 'Gaby', 'cards': [('A', 'Spade'), ('K', 'Spade')], 'blind': '', 'money': 1000}, {'name': 'Axel', 'cards': [('A', 'Clubs'), ('K', 'Clubs')], 'blind': '', 'money': 1000}, {'name': 'Lisa', 'cards': [('A', 'Diamonds'), ('K', 'Diamonds')], 'blind': '', 'money': 1000}]
